# %%
import sys
sys.path.append('..')
import util as ut
import dynamicProg as dp
import numpy as np
import matplotlib.pyplot as plt

# %%
S = 4; A = 2; I = 3; 
P = np.zeros((S,S,A,I))
C = np.random.rand(S,A);
# C = np.zeros((S,A))
for s in range(S):
    for a in range(A):
        for ind in range(I):
            P[:,s, a, ind]  = np.random.rand(S);
            P[:,s, a, ind] = P[:,s, a, ind]/np.sum(P[:,s, a, ind]);
np.set_printoptions(precision=2)
# for a in range(A):
#     for s in range(S):
#         print("For state ", s, " action #", a)
#         print(P[:,s,a,:])

# %%
# construct over approximating P:
overP = np.zeros((S,S,A,S));
for s in range(S):
    for a in range(A): 
        Pmin = np.min(P[:,s, a, :], axis = 1);
        minSum = np.sum(Pmin);
        for ind in range(S):
            overP[:,s,a,ind] = Pmin;
            overP[ind, s, a, ind] += 1. - minSum;

# %%
# print ((overP[:,0,0,:]))

# %%
def valueIteration(P, C, V, gamma = 0.9):
    S, S, A, I = P.shape;
#     print(S)
    Vnext =  float("inf")*np.ones(S);
    for s in range(S):
        for a in range(A):
            for i in range(I):
                VnewS = (C[s,a] + gamma*V.T.dot(P[:,s,a,i]));
                if VnewS < Vnext[s]:
                    Vnext[s] = 1.*VnewS;
    return Vnext;
def vI_oneStep(P, C, V, gamma = 0.9):
    S,S,A = P.shape;
    Vnext =  float("inf")*np.ones(S);
    for s in range(S):
        for a in range(A):
            VnewS = (C[s,a] + gamma*V.T.dot(P[:,s,a]));
            if VnewS < Vnext[s]:
                Vnext[s] = 1.*VnewS;
#     print (V.T.dot(P));
#     print (C + gamma*np.reshape(V.T.dot(P), (S,A)));
#     print (np.min(C + gamma*np.reshape(V.T.dot(P), (S,A)), axis = 1))
# np.min(C + gamma*np.reshape(V.T.dot(P), (S,A)), axis = 1)
    return Vnext;

def valueIteration_max(P, C, V, gamma = 0.9):
    S, S, A, I = P.shape;
#     print(S)
    Vnext =  float("-inf")*np.ones(S);
    for s in range(S):
        q = np.zeros(A);
        for a in range(A):
            qa = np.zeros(I);
            for i in range(I):
                qa[i] = (C[s,a] + gamma*V.T.dot(P[:,s,a,i]));
            q[a] = np.max(qa);
        Vnext[s] = np.min(q)
    return Vnext;
# def valueIteration_absoluteMin(P,C,V, gamma = 0.9):
#     S, S, A, I = P.shape;
#     Pmin= np.zeros((S,S,A));
#     Vnext =  np.zeros(S);
#     for s in range(S):
#         Qs = np.zeros(A);
#         for a in range(A):
#             Pmat = P[:,s, a, :];
#             Pmin[:,s,a] = np.min(Pmat, axis = 1)
#             Qs[a] = C[s,a] + gamma*np.min(V.T.dot(np.min(Pmat, axis = 0)));
#         Vnext[s] = np.min(Qs);
# #     return np.min(C + gamma*;
#     return Vnext;

# def valueIteration_absoluteMax(P,C,V, gamma = 0.9):
#     S, S, A, I = P.shape;
#     Pmax= np.zeros((S,S,A));
#     Vnext =  np.zeros(S);
#     for s in range(S):
#         Qs = np.zeros(A);
#         for a in range(A):
#             Pmat = P[:,s, a, :];
#             Pmax[:,s,a] = np.max(Pmat, axis = 1)
#             Qs[a] = C[s,a] + gamma*np.min(V.T.dot(Pmax));
# #             for sP in range(S):
# #                 Pmax[sP,s,a] = np.max(P[sP,s, a, :]);
# #                 print (np.max(Pmat, axis = 1))
# #             Qs[a] = C[s,a] + gamma*(V.T.dot(Pmax[:, s, a]));
#         Vnext[s] = np.max(Qs);
# #     return np.min(C + gamma*;
#     return Vnext;

# %%
V0 = np.random.rand(S);
# print (S)
# VlMinBound = valueIteration_absoluteMin(P,C,V);
# VlBound = valueIteration(P,C,V0);
Samples  = 10;
Iterations = 100;
Vrandom = np.zeros((S, Iterations, Samples));
Vbound = np.zeros((S,Iterations));
VupBound = np.zeros((S,Iterations));
# VMinBound = np.zeros((S, Iterations))  
# VMaxBound = np.zeros((S,Iterations));

for sample in range(Samples):
    # random samples of the probability kernel
    Psample = np.zeros((S,S,A));
    for s in range(S):
        for a in range(A):
            convexVec = np.random.rand(I);
            convexVec = convexVec/np.sum(convexVec);
            for i in range(I):
                Psample[:,s,a] += P[:,s,a,i]*convexVec[i];
#             print (np.sum(convexVec))
    # iterate over values        
    for k in range(Iterations):
        if k == 0:
            if sample == 0:
                Vbound[:,k] = V0;
                VupBound[:,k] = V0;
#                 print(Vbound[:,k])
#                 VMinBound[:, k] = V0;
#                 VMaxBound[:, k] = V0;
            Vrandom[:,k, sample] = V0;
#             print (Vrandom[:,k, sample])
        else:
            if sample == 0:
                Vbound[:,k] = valueIteration(P,C,Vbound[:,k-1]);
                VupBound[:,k] = valueIteration_max(P, C, VupBound[:,k-1]);
#                 VMinBound[:, k] = valueIteration_absoluteMin(P, C, VMinBound[:, k-1]);
#                 VMaxBound[:, k] = valueIteration_absoluteMax(P, C, VMaxBound[:, k-1]);
            Vrandom[:,k, sample] = vI_oneStep(Psample,C, Vrandom[:, k-1, sample]);

# %%
print (Psample)
# Out:
# [[[0.37 0.27]
#   [0.34 0.29]
#   [0.3  0.18]
#   [0.44 0.12]]
#
#  [[0.22 0.21]
#   [0.2  0.1 ]
#   [0.49 0.31]
#   [0.08 0.38]]
#
#  [[0.15 0.22]
#   [0.27 0.25]
#   [0.07 0.31]
#   [0.25 0.2 ]]
#
#  [[0.27 0.3 ]
#   [0.19 0.36]
#   [0.14 0.2 ]
#   [0.22 0.3 ]]]

# %%
iteration = 1;
plt.figure();
for i in range(Samples):
    plt.scatter(np.linspace(1,S,S), Vrandom[:,iteration, i]);
plt.grid();
plt.scatter(np.linspace(1,S,S), Vbound[:,iteration], s = 150);
plt.scatter(np.linspace(1,S,S), VupBound[:,iteration], s = 150);
# plt.scatter(np.linspace(1,S,S), VMinBound[:,iteration], s = 150)
# plt.scatter(np.linspace(1,S,S), VMaxBound[:,iteration], s = 150)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
iteration =99;
plt.figure();
for i in range(Samples):
    plt.scatter(np.linspace(1,S,S), Vrandom[:,iteration, i]);
plt.grid();
plt.scatter(np.linspace(1,S,S), Vbound[:,iteration], s = 150);
plt.scatter(np.linspace(1,S,S), VupBound[:,iteration], s = 150);
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.figure()
plt.plot(np.linspace(0, Iterations, Iterations), Vbound[0, :])
plt.plot(np.linspace(0, Iterations, Iterations), Vbound[1, :])
plt.plot(np.linspace(0, Iterations, Iterations), Vbound[2, :])
plt.grid();
# plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.figure()
plt.plot(np.linspace(0, Iterations, Iterations), VMaxBound[0, :])
plt.plot(np.linspace(0, Iterations, Iterations), VMaxBound[1, :])
plt.plot(np.linspace(0, Iterations, Iterations), VMaxBound[2, :])
plt.grid();
# plt.yscale('log')
